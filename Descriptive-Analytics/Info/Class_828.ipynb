# %%
import matplotlib.pyplot as plt

# %%
time = ['mo', 'tu', 'we', 'th', 'fr']
med = [2, 4, 7, 5, 6]

# %%
plt.figure(figsize=(6,3))
plt.plot(time, med)
plt.title("pizza")
plt.xlabel("time")
plt.ylabel("med")
plt.grid(True)
plt.show()
