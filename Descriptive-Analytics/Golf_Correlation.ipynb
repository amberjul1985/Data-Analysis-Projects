# %%
import numpy as np
import pandas as pd

# %%
# # Load data
Golf_df = pd.read_csv('Golf_Stats_2016.csv') # importing the csv file

# #Renaming Columns
Golf_df.columns = [s.strip().replace(' ', '_') for s in Golf_df.columns] # all columns


# # Descriptive statistics
print(Golf_df.describe()) # show summary statistics for each column
# Out:
#              Rank         Age     Events      Rounds   Cuts_Made     Top_10s  \
# count  200.000000  187.000000  200.00000  200.000000  200.000000  200.000000
# mean   100.500000   35.374332   22.78500   72.180000   14.465000    2.610000
# std     57.879185    6.816251    6.19278   20.355573    4.799369    2.493791
# min      1.000000   22.000000    4.00000   14.000000    3.000000    0.000000
# 25%     50.750000   30.000000   20.00000   62.750000   11.000000    1.000000
# 50%    100.500000   34.000000   25.00000   77.000000   15.000000    2.000000
# 75%    150.250000   40.000000   27.00000   86.000000   18.000000    4.000000
# max    200.000000   55.000000   34.00000  111.000000   25.000000   15.000000
#
#              Wins      Earnings  Yards/Drive  Driving_Accuracy  \
# count  200.000000  2.000000e+02   169.000000        169.000000
# mean     0.225000  1.540167e+06   291.128402         60.333136
# std      0.525123  1.411250e+06     8.706799          5.095630
# min      0.000000  2.771180e+05   269.700000         43.000000
# 25%      0.000000  5.945655e+05   285.900000         57.200000
# 50%      0.000000  1.083471e+06   290.100000         60.500000
# 75%      0.000000  1.910423e+06   296.300000         63.800000
# max      3.000000  9.365185e+06   314.500000         73.400000
#
#        Greens_in_Regulation  Putting_Average  Sand_Save_Pct      Eagles  \
# count            169.000000       169.000000     169.000000  195.000000
# mean              65.800592         1.772426      49.937278    6.353846
# std                2.596300         0.022321       5.542098    3.285853
# min               54.500000         1.710000      38.200000    1.000000
# 25%               64.000000         1.760000      45.600000    4.000000
# 50%               65.800000         1.770000      50.000000    6.000000
# 75%               67.800000         1.790000      54.300000    8.000000
# max               71.600000         1.840000      62.400000   16.000000
#
#           Birdies         Pars      Bogies
# count  195.000000   195.000000  195.000000
# mean   259.328205   832.707692  192.323077
# std     75.252051   226.135466   50.438829
# min     47.000000   164.000000   25.000000
# 25%    215.000000   731.000000  168.000000
# 50%    272.000000   873.000000  204.000000
# 75%    309.000000   996.500000  226.000000
# max    400.000000  1278.000000  288.000000

# %%
df = pd.DataFrame(Golf_df)
# print(df)
df_mn = df.fillna(df.mean(numeric_only=True))
# print(df_mn)

# #Finding Correlation
correlation_matrix = df_mn.corr()
print(correlation_matrix)
# Out:
#                           Rank       Age    Events    Rounds  Cuts_Made  \
# Rank                  1.000000  0.144539 -0.230715 -0.443830  -0.677826
# Age                   0.144539  1.000000 -0.162496 -0.161551  -0.176074
# Events               -0.230715 -0.162496  1.000000  0.948268   0.722791
# Rounds               -0.443830 -0.161551  0.948268  1.000000   0.895642
# Cuts_Made            -0.677826 -0.176074  0.722791  0.895642   1.000000
# Top_10s              -0.801995 -0.186921  0.132833  0.311138   0.532494
# Wins                 -0.572802 -0.153159  0.030403  0.141457   0.299234
# Earnings             -0.833929 -0.159845  0.100223  0.291769   0.539787
# Yards/Drive          -0.249571 -0.264953 -0.017846  0.044352   0.151822
# Driving_Accuracy     -0.032256  0.146710 -0.026571  0.010508   0.021750
# Greens_in_Regulation -0.258889 -0.017977 -0.040095  0.072611   0.212668
# Putting_Average       0.364319  0.129630 -0.006075 -0.097365  -0.212449
# Sand_Save_Pct        -0.208902 -0.036838  0.009591  0.053485   0.122009
# Eagles               -0.359746 -0.158826  0.402519  0.477948   0.501866
# Birdies              -0.520278 -0.163138  0.825080  0.917078   0.884343
# Pars                 -0.384606 -0.087871  0.887006  0.943005   0.846240
# Bogies               -0.288808 -0.116916  0.874142  0.892657   0.763668
#
#                        Top_10s      Wins  Earnings  Yards/Drive  \
# Rank                 -0.801995 -0.572802 -0.833929    -0.249571
# Age                  -0.186921 -0.153159 -0.159845    -0.264953
# Events                0.132833  0.030403  0.100223    -0.017846
# Rounds                0.311138  0.141457  0.291769     0.044352
# Cuts_Made             0.532494  0.299234  0.539787     0.151822
# Top_10s               1.000000  0.612242  0.888087     0.316717
# Wins                  0.612242  1.000000  0.807257     0.274141
# Earnings              0.888087  0.807257  1.000000     0.355733
# Yards/Drive           0.316717  0.274141  0.355733     1.000000
# Driving_Accuracy     -0.061663 -0.091413 -0.070776    -0.571452
# Greens_in_Regulation  0.268460  0.140700  0.278227     0.392201
# Putting_Average      -0.430543 -0.305299 -0.408644    -0.028534
# Sand_Save_Pct         0.161074  0.068775  0.157773    -0.170357
# Eagles                0.345372  0.236195  0.391141     0.355337
# Birdies               0.440713  0.236366  0.415071     0.163615
# Pars                  0.271417  0.102997  0.241771    -0.012781
# Bogies                0.147442  0.059464  0.146247     0.037124
#
#                       Driving_Accuracy  Greens_in_Regulation  Putting_Average  \
# Rank                         -0.032256             -0.258889         0.364319
# Age                           0.146710             -0.017977         0.129630
# Events                       -0.026571             -0.040095        -0.006075
# Rounds                        0.010508              0.072611        -0.097365
# Cuts_Made                     0.021750              0.212668        -0.212449
# Top_10s                      -0.061663              0.268460        -0.430543
# Wins                         -0.091413              0.140700        -0.305299
# Earnings                     -0.070776              0.278227        -0.408644
# Yards/Drive                  -0.571452              0.392201        -0.028534
# Driving_Accuracy              1.000000              0.230040         0.166962
# Greens_in_Regulation          0.230040              1.000000         0.243090
# Putting_Average               0.166962              0.243090         1.000000
# Sand_Save_Pct                -0.015896             -0.219284        -0.287414
# Eagles                       -0.110273              0.198241        -0.166963
# Birdies                      -0.030448              0.164566        -0.246081
# Pars                          0.064293              0.087954        -0.061134
# Bogies                       -0.077182             -0.078856        -0.026003
#
#                       Sand_Save_Pct    Eagles   Birdies      Pars    Bogies
# Rank                      -0.208902 -0.359746 -0.520278 -0.384606 -0.288808
# Age                       -0.036838 -0.158826 -0.163138 -0.087871 -0.116916
# Events                     0.009591  0.402519  0.825080  0.887006  0.874142
# Rounds                     0.053485  0.477948  0.917078  0.943005  0.892657
# Cuts_Made                  0.122009  0.501866  0.884343  0.846240  0.763668
# Top_10s                    0.161074  0.345372  0.440713  0.271417  0.147442
# Wins                       0.068775  0.236195  0.236366  0.102997  0.059464
# Earnings                   0.157773  0.391141  0.415071  0.241771  0.146247
# Yards/Drive               -0.170357  0.355337  0.163615 -0.012781  0.037124
# Driving_Accuracy          -0.015896 -0.110273 -0.030448  0.064293 -0.077182
# Greens_in_Regulation      -0.219284  0.198241  0.164566  0.087954 -0.078856
# Putting_Average           -0.287414 -0.166963 -0.246081 -0.061134 -0.026003
# Sand_Save_Pct              1.000000 -0.094384  0.074007  0.082589 -0.042539
# Eagles                    -0.094384  1.000000  0.537783  0.473074  0.474822
# Birdies                    0.074007  0.537783  1.000000  0.944465  0.885010
# Pars                       0.082589  0.473074  0.944465  1.000000  0.915663
# Bogies                    -0.042539  0.474822  0.885010  0.915663  1.000000

# %%
# # # Visualize the finding
import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(correlation_matrix, annot=True)
plt.show()
